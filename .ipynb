# %% [markdown]
# # Mod 2 - Project 2
# ## Salary Prediction Model for NYC Jobs

# %% [markdown]
# #### Deliverables
# - A well-formed hypothesis and the question you are trying to answer
# - Data visualization showing correlations between variables and distributions of data
# - Exploratory analysis of your data
# - Results of your hypothesis testing with evaluation metrics (R square, coefficients of variables, your model)
# - A model with at least **three** distinct independent variables, and **two** engineered features
# - Examination of linear model assumptions using visualizations
# - A coherent and insightful story

# %%
#!/usr/bin/env python

import pandas as pd
from sodapy import Socrata
import sqlite3
import numpy as np
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
import matplotlib.pyplot as plt
# %matplotlib inline


url = 'https://data.cityofnewyork.us/resource/kpav-sd4t.json'

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", None)

# Max 4000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("kpav-sd4t", limit=4000)

# Convert to pandas DataFrame
df = pd.DataFrame.from_records(results)
print(df.shape)
df.head()
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.
#   __of_positions                             additional_information  \
# 0              1  Salary range for this position is: $42,405 - $...
# 1              1                                                NaN
# 2             52  1.  A Motor Vehicle Driverâ€™s License valid i...
# 3             52  1.  A Motor Vehicle Driverâ€™s License valid i...
# 4             50  SPECIAL NOTE:    1.  This is a temporary assig...
#
#                          agency  \
# 0  DEPARTMENT OF BUSINESS SERV.
# 1  DEPARTMENT OF BUSINESS SERV.
# 2         NYC HOUSING AUTHORITY
# 3         NYC HOUSING AUTHORITY
# 4         NYC HOUSING AUTHORITY
#
#                                       business_title  \
# 0                                    Account Manager
# 1           EXECUTIVE DIRECTOR, BUSINESS DEVELOPMENT
# 2  Maintenance Worker - Technical Services-Heatin...
# 3  Maintenance Worker - Technical Services-Heatin...
# 4                                  Temporary Painter
#
#               civil_service_title              division_work_unit  \
# 0  CONTRACT REVIEWER (OFFICE OF L            Strategy & Analytics
# 1  ADMINISTRATIVE BUSINESS PROMOT            Tech Talent Pipeline
# 2              MAINTENANCE WORKER  Management Services Department
# 3              MAINTENANCE WORKER  Management Services Department
# 4                         PAINTER   Dept of Management & Planning
#
#   full_time_part_time_indicator hours_shift              job_category  \
# 0                           NaN         NaN                       NaN
# 1                             F         NaN                       NaN
# 2                             F         NaN  Maintenance & Operations
# 3                             F         NaN  Maintenance & Operations
# 4                             F         NaN  Maintenance & Operations
#
#                                      job_description       ...        \
# 0  Division of Economic & Financial Opportunity (...       ...
# 1  The New York City Department of Small Business...       ...
# 2  Under direct supervision, assist in the routin...       ...
# 3  Under direct supervision, assist in the routin...       ...
# 4  Responsibilities of selected candidates will i...       ...
#
#                                     preferred_skills             process_date  \
# 0  â€¢\tExcellent interpersonal and organizationa...  2019-04-16T00:00:00.000
# 1                                                NaN  2019-04-16T00:00:00.000
# 2  1.  A High School Diploma or GED.  2.  CDL Dri...  2019-04-16T00:00:00.000
# 3  1.  A High School Diploma or GED.  2.  CDL Dri...  2019-04-16T00:00:00.000
# 4                                                NaN  2019-04-16T00:00:00.000
#
#                                residency_requirement salary_frequency  \
# 0  New York City residency is generally required ...           Annual
# 1  New York City residency is generally required ...           Annual
# 2               NYCHA has no residency requirements.           Annual
# 3               NYCHA has no residency requirements.           Annual
# 4                NYCHA has no residency requirement.           Hourly
#
#   salary_range_from salary_range_to title_code_no  \
# 0             42405           65485         40563
# 1             60740          162014         10009
# 2          51907.68        54580.32         90698
# 3          51907.68        54580.32         90698
# 4                35              35         91830
#
#                                             to_apply  \
# 0                                                NaN
# 1  In addition to applying through this website, ...
# 2                      Click the "Apply Now" button.
# 3                      Click the "Apply Now" button.
# 4                      Click the "Apply Now" button.
#
#                   work_location work_location_1
# 0           110 William St. N Y             NaN
# 1           110 William St. N Y             NaN
# 2        Heating Mgt-Operations             NaN
# 3        Heating Mgt-Operations             NaN
# 4  DMP-Contract & Analysis Unit             NaN
#
# [5 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3494 entries, 0 to 3493
# Data columns (total 27 columns):
# __of_positions                   3494 non-null object
# additional_information           2242 non-null object
# agency                           3494 non-null object
# business_title                   3494 non-null object
# civil_service_title              3494 non-null object
# division_work_unit               3494 non-null object
# full_time_part_time_indicator    3217 non-null object
# hours_shift                      1006 non-null object
# job_category                     3492 non-null object
# job_description                  3494 non-null object
# job_id                           3494 non-null object
# level                            3494 non-null object
# minimum_qual_requirements        3474 non-null object
# post_until                       1156 non-null object
# posting_date                     3494 non-null object
# posting_type                     3494 non-null object
# posting_updated                  3494 non-null object
# preferred_skills                 3017 non-null object
# process_date                     3494 non-null object
# residency_requirement            3494 non-null object
# salary_frequency                 3494 non-null object
# salary_range_from                3494 non-null object
# salary_range_to                  3494 non-null object
# title_code_no                    3494 non-null object
# to_apply                         3493 non-null object
# work_location                    3494 non-null object
# work_location_1                  1497 non-null object
# dtypes: object(27)
# memory usage: 737.1+ KB

# %%
# Create SQL Database & Tables for Lionsgate WS Data
# Then create a dataframe for the data

conn = sqlite3.connect('nycjobs.db')
c = conn.cursor()
df.to_sql('AllNYCJobs', conn, if_exists='replace')
# Out:
# (3494, 27)

# %%
### Export DataFrames to csv file

# df.to_csv('AllNYCJobs.csv')

#### SQL Queries for reference 

#print(c.execute('''SELECT * from Lionsgate_WS_S''').fetchall())
c.execute('''PRAGMA table_info(AllNYCJobs)''').fetchall()
